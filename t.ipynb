# %%
pip install streamlit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st
import os
import warnings
import logging

# Suppress specific warnings
warnings.filterwarnings("ignore", category=UserWarning, message="missing ScriptRunContext")

# Configure logging level to suppress warnings
logging.getLogger("streamlit").setLevel(logging.ERROR)

# Configure Google Gemini API Key
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")
if not GEMINI_API_KEY:
    st.error("Please set the GEMINI_API_KEY environment variable.")
    st.stop()

# Assuming you have a function to configure and use the Google Gemini API
def configure_genai(api_key):
    # Placeholder for actual configuration code
    pass

def generate_content(prompt):
    # Placeholder for actual content generation code
    return "This is a placeholder response. Replace this with actual API call."

configure_genai(GEMINI_API_KEY)

def review_code(code):
    """Send code to Gemini API for review."""
    prompt = f"""
    Analyze the following Python code for bugs, optimizations, and best practices.
    Provide a review with necessary improvements:

    python
    {code}
    """
    response = generate_content(prompt)
    return response

# Streamlit UI
st.set_page_config(page_title="AI Code Reviewer", layout="wide")
st.title("🔍 AI Code Reviewer")
st.markdown("Upload or paste your Python code to get an AI-powered review.")

# Text area for code input
code = st.text_area("Paste your Python code here:", height=250)

if st.button("Review Code"):
    if code.strip():
        with st.spinner("Analyzing your code..."):
            review = review_code(code)
            st.subheader("AI Review Report")
            st.markdown(review)
    else:
        st.warning("Please enter some Python code to review.")
# Out:
# 2025-02-20 20:06:44.264 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-20 20:06:44.265 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-20 20:06:44.267 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-20 20:06:44.269 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-20 20:06:44.269 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-20 20:06:44.270 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-20 20:06:44.271 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
import streamlit as st
import os
import warnings
import logging

# Suppress specific warnings
warnings.filterwarnings("ignore", category=UserWarning, message="missing ScriptRunContext")

# Configure logging level to suppress warnings
logging.getLogger("streamlit").setLevel(logging.ERROR)

# Configure Google Gemini API Key
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")
if not GEMINI_API_KEY:
    st.error("Please set the GEMINI_API_KEY environment variable.")
    st.stop()

# Assuming you have a function to configure and use the Google Gemini API
def configure_genai(api_key):
    # Placeholder for actual configuration code
    pass

def generate_content(prompt):
    # Placeholder for actual content generation code
    return "This is a placeholder response. Replace this with actual API call."

configure_genai(GEMINI_API_KEY)

def review_code(code):
    """Send code to Gemini API for review."""
    prompt = f"""
    Analyze the following Python code for bugs, optimizations, and best practices.
    Provide a review with necessary improvements:

    python
    {code}
    """
    response = generate_content(prompt)
    return response

# Streamlit UI
st.set_page_config(page_title="AI Code Reviewer", layout="wide")
st.title("🔍 AI Code Reviewer")
st.markdown("Upload or paste your Python code to get an AI-powered review.")

# Text area for code input
code = st.text_area("Paste your Python code here:", height=250)

if st.button("Review Code"):
    if code.strip():
        with st.spinner("Analyzing your code..."):
            review = review_code(code)
            st.subheader("AI Review Report")
            st.markdown(review)
    else:
        st.warning("Please enter some Python code to review.")
# Out:
# 2025-02-20 20:07:08.262 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-20 20:07:08.263 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-20 20:07:08.264 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-20 20:07:08.265 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-20 20:07:08.266 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-20 20:07:08.267 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-20 20:07:08.268 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
import streamlit as st
import google.generativeai as genai
import os
import warnings
import logging

# Suppress specific warnings
warnings.filterwarnings("ignore", message="missing ScriptRunContext")

# Configure logging level to suppress warnings
logging.getLogger("streamlit").setLevel(logging.ERROR)

# Configure Google Gemini API Key
GEMINI_API_KEY = os.getenv("AIzaSyB31_fZUKmS54wvWUxto9powKQApOjdCZs")
if not GEMINI_API_KEY:
    st.error("Please set the GEMINI_API_KEY environment variable.")
    st.stop()

# Assuming you have a function to configure and use the Google Gemini API
def configure_genai(api_key):
    # Placeholder for actual configuration code
    pass

def generate_content(prompt):
    # Placeholder for actual content generation code
    return "This is a placeholder response. Replace this with actual API call."

configure_genai(GEMINI_API_KEY)

def review_code(code):
    """Send code to Gemini API for review."""
    prompt = f"""
    Analyze the following Python code for bugs, optimizations, and best practices.
    Provide a review with necessary improvements:

    python
    {code}
    """
    response = generate_content(prompt)
    return response

# Streamlit UI
st.set_page_config(page_title="AI Code Reviewer", layout="wide")
st.title("🔍 AI Code Reviewer")
st.markdown("Upload or paste your Python code to get an AI-powered review.")

# Text area for code input
code = st.text_area("Paste your Python code here:", height=250)

if st.button("Review Code"):
    if code.strip():
        with st.spinner("Analyzing your code..."):
            review = review_code(code)
            st.subheader("AI Review Report")
            st.markdown(review)
    else:
        st.warning("Please enter some Python code to review.")
# Out:
# 2025-02-20 20:17:12.549 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-20 20:17:12.552 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-20 20:17:12.556 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-20 20:17:12.558 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-20 20:17:12.560 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-20 20:17:12.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-20 20:17:12.565 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
